# %%
import numpy as np
import pandas as pd

options = pd.read_csv('Downloads/XternData.csv')

import googlemaps
import requests

gmaps = googlemaps.Client(key='API_KEY') #I have not disclosed mine for security reasons

name = []
address = []
rating = []
classifier = []

for i in range(50): #Looks up different places to eat in Indianapolis 50 times and stores results
    url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input="+ str(i) +"%20places%20to%20eat%20in%20Indianapolis&inputtype=textquery&fields=formatted_address%2Cname%2Crating&key=API_KEY"

    payload={}
    headers = {}

    response = requests.request("GET", url, headers=headers, data=payload)
    
    name.append(response.json()["candidates"][0]["name"])
    address.append(response.json()["candidates"][0]["formatted_address"])
    rating.append(response.json()["candidates"][0]["rating"])
    classifier.append("Food")

d = {'Name': name, 
     'Category': classifier,
     'Address': address,
     'Rating': rating}
df1 = pd.DataFrame(data=d) #Creates pandas dataframe with data

name = []
address = []
rating = []
category = []
for i in range(10): #Looks up 10 different fields and arenas and stores result
    url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=" + str(i) + "%20Fields%20Arenas%20stadiums%20Indianapolis&inputtype=textquery&fields=formatted_address%2Cname%2Crating&key=API_KEY"
    
    payload={}
    headers = {}

    response = requests.request("GET", url, headers=headers, data=payload)
    
    names.append(response.json()["candidates"][0]["name"])
    address.append(response.json()["candidates"][0]["formatted_address"])
    rating.append(response.json()["candidates"][0]["rating"])
    category.append("Sport")

d = {'Name': names, 
     'Category': category,
     'Address': address,
     'Rating': rating}
df2 = pd.DataFrame(data=d)
df2 = df2.drop_duplicates(subset=None, keep='first', inplace=False) #removes duplicate entries
df1 = df1.append(df2)  #Gets added to existing data frame

names = []
address = []
rating = []
category = []
for i in range(1,5):  #Looks up 5 different Music places and stores result
    url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=" + str(i) + "%20Music%20Indianapolis&inputtype=textquery&fields=formatted_address%2Cname%2Crating&key=API_KEY"
    
    payload={}
    headers = {}

    response = requests.request("GET", url, headers=headers, data=payload)
    
    names.append(response.json()["candidates"][0]["name"])
    address.append(response.json()["candidates"][0]["formatted_address"])
    rating.append(response.json()["candidates"][0]["rating"])
    category.append("Music")

d = {'Name': names, 
     'Category': category,
     'Address': address,
     'Rating': rating}
df2 = pd.DataFrame(data=d)
df2 = df2.drop_duplicates(subset=None, keep='first', inplace=False)
df1 = df1.append(df2)  #Gets added to existing data frame

names = []
address = []
rating = []
category = []
for i in range(5):  #Looks up 5 different game locations and stores result
    url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=" + str(i) + "%20Game%20Indianapolis&inputtype=textquery&fields=formatted_address%2Cname%2Crating&key=API_KEY"
    
    payload={}
    headers = {}

    response = requests.request("GET", url, headers=headers, data=payload)
    
    names.append(response.json()["candidates"][0]["name"])
    address.append(response.json()["candidates"][0]["formatted_address"])
    rating.append(response.json()["candidates"][0]["rating"])
    category.append("Gaming")

d = {'Name': names, 
     'Category': category,
     'Address': address,
     'Rating': rating}
df2 = pd.DataFrame(data=d)
df2 = df2.drop_duplicates(subset=None, keep='first', inplace=False)
df1 = df1.append(df2)  #Gets added to existing data frame

df2 = df1.reset_index()
df2
# Out:
# 0
# 1
# 2

# %%
milesIUPUI = []
minIUPUI = []
for i in range(len(df2)):
    one = options.loc[0,'Address'].replace(" ", "%20").replace("#", "") #Formats each address for URL
    two = df2.loc[i,'Address'].replace(" ", "%20").replace("#", "")

    url = "https://maps.googleapis.com/maps/api/distancematrix/json?origins=" + one + "%2C%20DC&destinations=" + two + "%2C%20NY&units=imperial&key=API_KEY"

    payload= {}
    headers = {}

    response = requests.request("GET", url, headers=headers, data=payload)

    a = float(response.json()['rows'][0]['elements'][0]['distance']['text'].split()[0]) #Gets distance in miles
    b = float(response.json()['rows'][0]['elements'][0]['duration']['text'].split()[0]) #Gets distance in minutes
    milesIUPUI.append(a)
    minIUPUI.append(b)
    


miles1 = []
min1 = []
for i in range(len(df2)):
    one = options.loc[1,'Address'].replace(" ", "%20").replace("#", "")
    two = df2.loc[i,'Address'].replace(" ", "%20").replace("#", "")

    url = "https://maps.googleapis.com/maps/api/distancematrix/json?origins=" + one + "%2C%20DC&destinations=" + two + "%2C%20NY&units=imperial&key=API_KEY"

    payload= {}
    headers = {}

    response = requests.request("GET", url, headers=headers, data=payload)

    a = float(response.json()['rows'][0]['elements'][0]['distance']['text'].split()[0])
    b = float(response.json()['rows'][0]['elements'][0]['duration']['text'].split()[0])
    miles1.append(a)
    min1.append(b)
    


miles2 = []
min2 = []
for i in range(len(df2)):
    one = options.loc[2,'Address'].replace(" ", "%20").replace("#", "")
    two = df2.loc[i,'Address'].replace(" ", "%20").replace("#", "")

    url = "https://maps.googleapis.com/maps/api/distancematrix/json?origins=" + one + "%2C%20DC&destinations=" + two + "%2C%20NY&units=imperial&key=API_KEY"

    payload= {}
    headers = {}

    response = requests.request("GET", url, headers=headers, data=payload)

    a = float(response.json()['rows'][0]['elements'][0]['distance']['text'].split()[0])
    b = float(response.json()['rows'][0]['elements'][0]['duration']['text'].split()[0])
    miles2.append(a)
    min2.append(b)


miles3 = []
min3 = []
for i in range(len(df2)):
    one = options.loc[3,'Address'].replace(" ", "%20").replace("#", "")
    two = df2.loc[i,'Address'].replace(" ", "%20").replace("#", "")

    url = "https://maps.googleapis.com/maps/api/distancematrix/json?origins=" + one + "%2C%20DC&destinations=" + two + "%2C%20NY&units=imperial&key=API_KEY"

    payload= {}
    headers = {}

    response = requests.request("GET", url, headers=headers, data=payload)

    a = float(response.json()['rows'][0]['elements'][0]['distance']['text'].split()[0])
    b = float(response.json()['rows'][0]['elements'][0]['duration']['text'].split()[0])
    miles3.append(a)
    min3.append(b)


miles4 = []
min4 = []
for i in range(len(df2)):
    one = options.loc[4,'Address'].replace(" ", "%20").replace("#", "")
    two = df2.loc[i,'Address'].replace(" ", "%20").replace("#", "")

    url = "https://maps.googleapis.com/maps/api/distancematrix/json?origins=" + one + "%2C%20DC&destinations=" + two + "%2C%20NY&units=imperial&key=API_KEY"

    payload= {}
    headers = {}

    response = requests.request("GET", url, headers=headers, data=payload)

    a = float(response.json()['rows'][0]['elements'][0]['distance']['text'].split()[0])
    b = float(response.json()['rows'][0]['elements'][0]['duration']['text'].split()[0])
    miles4.append(a)
    min4.append(b)


miles5 = []
min5 = []
for i in range(len(df2)):
    one = options.loc[5,'Address'].replace(" ", "%20").replace("#", "")
    two = df2.loc[i,'Address'].replace(" ", "%20").replace("#", "")

    url = "https://maps.googleapis.com/maps/api/distancematrix/json?origins=" + one + "%2C%20DC&destinations=" + two + "%2C%20NY&units=imperial&key=API_KEY"

    payload= {}
    headers = {}

    response = requests.request("GET", url, headers=headers, data=payload)

    a = float(response.json()['rows'][0]['elements'][0]['distance']['text'].split()[0])
    b = float(response.json()['rows'][0]['elements'][0]['duration']['text'].split()[0])
    miles5.append(a)
    min5.append(b)

            
d = {'Distance(Miles) from IUPUI': milesIUPUI,
     'Distance(Minutes) from IUPUI': minIUPUI,
     'Distance(Miles) from Speak Easy': miles1,
     'Distance(Minutes) from Speak Easy': min1,
     'Distance(Miles) from zWorks': miles2,
     'Distance(Minutes) from zWorks': min2,
     'Distance(Miles) from Launch Fishers': miles3,
     'Distance(Minutes) from Launch Fisher': min3,
     'Distance(Miles) from IMA': miles4,
     'Distance(Minutes) from IMA': min4,
     'Distance(Miles) from Launch Indy': miles5,
     'Distance(Minutes) from Launch Indy': min5}
df3 = pd.DataFrame(data=d) #Creates datafarme of all the distaces

df5 = pd.concat([df2, df3], axis=1) #Adds new data to existing location dataframe
df5.to_csv('Locations of Interest and Distance from Housing and Coworking Spaces', sep='\t')
# Out:
# [2.6, 2.5, 20.1, 10.7, 7.1, 2.9, 1.8, 3.5, 2.2, 1.9, 20.3, 11.1, 2.0, 2.0, 2.0, 2.3, 2.0, 2.8, 6.5, 2.1, 2.2, 8.4, 731.0, 2.2, 3.0, 3.9, 2.2, 3.0, 3.9, 2.1, 2.0, 8.1, 7.4, 6.3]

# %%
import matplotlib.pyplot as plt

df4 = df3.drop(labels=[22], axis=0) #Drops outlier (spurious google result)

plt.barh(df4.columns.values.tolist(), df4.mean(), color = ['black', 'black', 'yellow', 'yellow', 'blue', 'blue', 'green', 'green', 'pink', 'pink', 'red', 'red'],
        alpha = 0.6, edgecolor = ['white', 'black']) #Creates bar graph of means for each coworking location

plt.show()

plt.savefig('Distances Visualized.png')
# Out:
#                                      Name        Type
# 0                    St. Elmo Steak House  Restaurant
# 1                          Bazbeaux Pizza  Restaurant
# 2                           Cafe Patachou  Restaurant
# 3                                    Yats  Restaurant
# 4                          Shapiro's Deli  Restaurant
# 5               Jockamo Upper Crust Pizza  Restaurant
# 6   Mama Carolla’s Old Italian Restaurant  Restaurant
# 7                          Harry & Izzy's  Restaurant
# 8                               Bluebeard  Restaurant
# 9                                  Livery  Restaurant
# 10                        The Rathskeller  Restaurant
# 11                       Goose the Market  Restaurant
# 12                   Rick's Cafe Boatyard  Restaurant
# 13                 Caplingers Fresh Catch  Restaurant
# 14             Iaria's Italian Restaurant  Restaurant
# 15                               Union 50  Restaurant
# 16                 Sahm's Tavern and Cafe  Restaurant
# 17                        Big Lug Canteen  Restaurant

# %%
# Out:
#                                Name Category  \
# 0                            Livery     Food
# 1                          Union 50     Food
# 2           Maggiano's Little Italy     Food
# 3                 3 in 1 Restaurant     Food
# 4                            Livery     Food
# 5                            Livery     Food
# 6                            Livery     Food
# 7         Meridian Restaurant & Bar     Food
# 8                            Livery     Food
# 9                            Livery     Food
# 10                        Bluebeard     Food
# 11                        The Eagle     Food
# 12          Iron Skillet Restaurant     Food
# 13                        The Eagle     Food
# 14                             Vida     Food
# 15                       Yard House     Food
# 16                       Seasons 52     Food
# 17                       Seasons 52     Food
# 18                       Seasons 52     Food
# 19                        The Eagle     Food
# 20                        The Eagle     Food
# 21                        Bluebeard     Food
# 22                       Seasons 52     Food
# 23                        The Eagle     Food
# 24          Leonardo's Mexican Food     Food
# 25                        The Eagle     Food
# 26                        Bluebeard     Food
# 27                        Bluebeard     Food
# 28                        Bluebeard     Food
# 29                        Bluebeard     Food
# 30                        The Eagle     Food
# 31                        The Eagle     Food
# 32                        Bluebeard     Food
# 33                       Bubba's 33     Food
# 34                        The Eagle     Food
# 35                    Buca di Beppo     Food
# 36                        Bluebeard     Food
# 37         Tinker Street Restaurant     Food
# 38                        Bluebeard     Food
# 39                        Bluebeard     Food
# 40                  1913 Restaurant     Food
# 41         Ruth's Chris Steak House     Food
# 42                        Bluebeard     Food
# 43                           Comida     Food
# 44           Weber Grill Restaurant     Food
# 45                FortyFive Degrees     Food
# 46                         TACOS 46     Food
# 47      Prime 47- Indy's Steakhouse     Food
# 48  Pier 48 Fish House & Oyster Bar     Food
# 49                        Bluebeard     Food
#
#                                               Address  Rating
# 0   720 N College Ave, Indianapolis, IN 46202, Uni...     4.7
# 1   620 N East St, Indianapolis, IN 46202, United ...     4.6
# 2   3550 E 86th St, Indianapolis, IN 46240, United...     4.4
# 3   1413 W 86th St, Indianapolis, IN 46260, United...     4.7
# 4   720 N College Ave, Indianapolis, IN 46202, Uni...     4.7
# 5   720 N College Ave, Indianapolis, IN 46202, Uni...     4.7
# 6   720 N College Ave, Indianapolis, IN 46202, Uni...     4.7
# 7   5694 N Meridian St, Indianapolis, IN 46208, Un...     4.5
# 8   720 N College Ave, Indianapolis, IN 46202, Uni...     4.7
# 9   720 N College Ave, Indianapolis, IN 46202, Uni...     4.7
# 10  653 Virginia Ave, Indianapolis, IN 46203, Unit...     4.7
# 11  310 Massachusetts Ave, Indianapolis, IN 46204,...     4.5
# 12  2489 W 30th St #2268, Indianapolis, IN 46222, ...     4.5
# 13  310 Massachusetts Ave, Indianapolis, IN 46204,...     4.5
# 14  601 E New York St, Indianapolis, IN 46202, Uni...     4.8
# 15  15 W Maryland St, Indianapolis, IN 46204, Unit...     4.4
# 16  8650 Keystone Crossing, Indianapolis, IN 46240...     4.5
# 17  8650 Keystone Crossing, Indianapolis, IN 46240...     4.5
# 18  8650 Keystone Crossing, Indianapolis, IN 46240...     4.5
# 19  310 Massachusetts Ave, Indianapolis, IN 46204,...     4.5
# 20  310 Massachusetts Ave, Indianapolis, IN 46204,...     4.5
# 21  653 Virginia Ave, Indianapolis, IN 46203, Unit...     4.7
# 22  8650 Keystone Crossing, Indianapolis, IN 46240...     4.5
# 23  310 Massachusetts Ave, Indianapolis, IN 46204,...     4.5
# 24  8431 N Michigan Rd, Indianapolis, IN 46268, Un...     4.2
# 25  310 Massachusetts Ave, Indianapolis, IN 46204,...     4.5
# 26  653 Virginia Ave, Indianapolis, IN 46203, Unit...     4.7
# 27  653 Virginia Ave, Indianapolis, IN 46203, Unit...     4.7
# 28  653 Virginia Ave, Indianapolis, IN 46203, Unit...     4.7
# 29  653 Virginia Ave, Indianapolis, IN 46203, Unit...     4.7
# 30  310 Massachusetts Ave, Indianapolis, IN 46204,...     4.5
# 31  310 Massachusetts Ave, Indianapolis, IN 46204,...     4.5
# 32  653 Virginia Ave, Indianapolis, IN 46203, Unit...     4.7
# 33  7799 US-31, Indianapolis, IN 46227, United States     4.4
# 34  310 Massachusetts Ave, Indianapolis, IN 46204,...     4.5
# 35  35 N Illinois St, Indianapolis, IN 46204, Unit...     4.1
# 36  653 Virginia Ave, Indianapolis, IN 46203, Unit...     4.7
# 37  402 E 16th St, Indianapolis, IN 46202, United ...     4.7
# 38  653 Virginia Ave, Indianapolis, IN 46203, Unit...     4.7
# 39  653 Virginia Ave, Indianapolis, IN 46203, Unit...     4.7
# 40  40 W Jackson Pl, Indianapolis, IN 46225, Unite...     4.4
# 41  45 S Illinois St, Indianapolis, IN 46204, Unit...     4.6
# 42  653 Virginia Ave, Indianapolis, IN 46203, Unit...     4.7
# 43   43 9th St, Indianapolis, IN 46204, United States     4.6
# 44  10 N Illinois St, Indianapolis, IN 46204, Unit...     4.2
# 45  765 Massachusetts Ave, Indianapolis, IN 46202,...     4.5
# 46  3089 N High School Rd, Indianapolis, IN 46224,...     4.4
# 47  47 S Pennsylvania St, Indianapolis, IN 46204, ...     4.6
# 48  130 S Pennsylvania St, Indianapolis, IN 46204,...     4.3
# 49  653 Virginia Ave, Indianapolis, IN 46203, Unit...     4.7

# %%
# Out:
#                                Name Category  \
# 0                            Livery     Food
# 1                          Union 50     Food
# 2           Maggiano's Little Italy     Food
# 3                 3 in 1 Restaurant     Food
# 7         Meridian Restaurant & Bar     Food
# 10                        Bluebeard     Food
# 11                        The Eagle     Food
# 12          Iron Skillet Restaurant     Food
# 14                             Vida     Food
# 15                       Yard House     Food
# 16                       Seasons 52     Food
# 24          Leonardo's Mexican Food     Food
# 35                    Buca di Beppo     Food
# 40                  1913 Restaurant     Food
# 41         Ruth's Chris Steak House     Food
# 43                           Comida     Food
# 44           Weber Grill Restaurant     Food
# 45                FortyFive Degrees     Food
# 46                         TACOS 46     Food
# 47      Prime 47- Indy's Steakhouse     Food
# 48  Pier 48 Fish House & Oyster Bar     Food
#
#                                               Address  Rating
# 0   720 N College Ave, Indianapolis, IN 46202, Uni...     4.7
# 1   620 N East St, Indianapolis, IN 46202, United ...     4.6
# 2   3550 E 86th St, Indianapolis, IN 46240, United...     4.4
# 3   1413 W 86th St, Indianapolis, IN 46260, United...     4.7
# 7   5694 N Meridian St, Indianapolis, IN 46208, Un...     4.5
# 10  653 Virginia Ave, Indianapolis, IN 46203, Unit...     4.7
# 11  310 Massachusetts Ave, Indianapolis, IN 46204,...     4.5
# 12  2489 W 30th St #2268, Indianapolis, IN 46222, ...     4.5
# 14  601 E New York St, Indianapolis, IN 46202, Uni...     4.8
# 15  15 W Maryland St, Indianapolis, IN 46204, Unit...     4.4
# 16  8650 Keystone Crossing, Indianapolis, IN 46240...     4.5
# 24  8431 N Michigan Rd, Indianapolis, IN 46268, Un...     4.2
# 35  35 N Illinois St, Indianapolis, IN 46204, Unit...     4.1
# 40  40 W Jackson Pl, Indianapolis, IN 46225, Unite...     4.4
# 41  45 S Illinois St, Indianapolis, IN 46204, Unit...     4.6
# 43   43 9th St, Indianapolis, IN 46204, United States     4.6
# 44  10 N Illinois St, Indianapolis, IN 46204, Unit...     4.2
# 45  765 Massachusetts Ave, Indianapolis, IN 46202,...     4.5
# 46  3089 N High School Rd, Indianapolis, IN 46224,...     4.4
# 47  47 S Pennsylvania St, Indianapolis, IN 46204, ...     4.6
# 48  130 S Pennsylvania St, Indianapolis, IN 46204,...     4.3

# %%
# Out:
#                                Name Category  \
# 0                            Livery     Food
# 1                          Union 50     Food
# 2           Maggiano's Little Italy     Food
# 3                 3 in 1 Restaurant     Food
# 7         Meridian Restaurant & Bar     Food
# 10                        Bluebeard     Food
# 11                        The Eagle     Food
# 12          Iron Skillet Restaurant     Food
# 14                             Vida     Food
# 15                       Yard House     Food
# 16                       Seasons 52     Food
# 24          Leonardo's Mexican Food     Food
# 35                    Buca di Beppo     Food
# 40                  1913 Restaurant     Food
# 41         Ruth's Chris Steak House     Food
# 43                           Comida     Food
# 44           Weber Grill Restaurant     Food
# 45                FortyFive Degrees     Food
# 46                         TACOS 46     Food
# 47      Prime 47- Indy's Steakhouse     Food
# 48  Pier 48 Fish House & Oyster Bar     Food
#
#                                               Address  Rating
# 0   720 N College Ave, Indianapolis, IN 46202, Uni...     4.7
# 1   620 N East St, Indianapolis, IN 46202, United ...     4.6
# 2   3550 E 86th St, Indianapolis, IN 46240, United...     4.4
# 3   1413 W 86th St, Indianapolis, IN 46260, United...     4.7
# 7   5694 N Meridian St, Indianapolis, IN 46208, Un...     4.5
# 10  653 Virginia Ave, Indianapolis, IN 46203, Unit...     4.7
# 11  310 Massachusetts Ave, Indianapolis, IN 46204,...     4.5
# 12  2489 W 30th St #2268, Indianapolis, IN 46222, ...     4.5
# 14  601 E New York St, Indianapolis, IN 46202, Uni...     4.8
# 15  15 W Maryland St, Indianapolis, IN 46204, Unit...     4.4
# 16  8650 Keystone Crossing, Indianapolis, IN 46240...     4.5
# 24  8431 N Michigan Rd, Indianapolis, IN 46268, Un...     4.2
# 35  35 N Illinois St, Indianapolis, IN 46204, Unit...     4.1
# 40  40 W Jackson Pl, Indianapolis, IN 46225, Unite...     4.4
# 41  45 S Illinois St, Indianapolis, IN 46204, Unit...     4.6
# 43   43 9th St, Indianapolis, IN 46204, United States     4.6
# 44  10 N Illinois St, Indianapolis, IN 46204, Unit...     4.2
# 45  765 Massachusetts Ave, Indianapolis, IN 46202,...     4.5
# 46  3089 N High School Rd, Indianapolis, IN 46224,...     4.4
# 47  47 S Pennsylvania St, Indianapolis, IN 46204, ...     4.6
# 48  130 S Pennsylvania St, Indianapolis, IN 46204,...     4.3

# %%
# Out:
#                                Name Category  \
# 0                            Livery     Food
# 1                          Union 50     Food
# 2           Maggiano's Little Italy     Food
# 3                 3 in 1 Restaurant     Food
# 7         Meridian Restaurant & Bar     Food
# 10                        Bluebeard     Food
# 11                        The Eagle     Food
# 12          Iron Skillet Restaurant     Food
# 14                             Vida     Food
# 15                       Yard House     Food
# 16                       Seasons 52     Food
# 24          Leonardo's Mexican Food     Food
# 35                    Buca di Beppo     Food
# 40                  1913 Restaurant     Food
# 41         Ruth's Chris Steak House     Food
# 43                           Comida     Food
# 44           Weber Grill Restaurant     Food
# 45                FortyFive Degrees     Food
# 46                         TACOS 46     Food
# 47      Prime 47- Indy's Steakhouse     Food
# 48  Pier 48 Fish House & Oyster Bar     Food
# 0       Kiesel Field at Key Stadium    Sport
# 3                     Victory Field    Sport
# 4             Gainbridge Fieldhouse    Sport
# 0              Classical Music Indy    Music
# 2          HI-FI Indy & HI-FI Annex    Music
# 3                     Music For All    Music
#
#                                               Address  Rating
# 0   720 N College Ave, Indianapolis, IN 46202, Uni...     4.7
# 1   620 N East St, Indianapolis, IN 46202, United ...     4.6
# 2   3550 E 86th St, Indianapolis, IN 46240, United...     4.4
# 3   1413 W 86th St, Indianapolis, IN 46260, United...     4.7
# 7   5694 N Meridian St, Indianapolis, IN 46208, Un...     4.5
# 10  653 Virginia Ave, Indianapolis, IN 46203, Unit...     4.7
# 11  310 Massachusetts Ave, Indianapolis, IN 46204,...     4.5
# 12  2489 W 30th St #2268, Indianapolis, IN 46222, ...     4.5
# 14  601 E New York St, Indianapolis, IN 46202, Uni...     4.8
# 15  15 W Maryland St, Indianapolis, IN 46204, Unit...     4.4
# 16  8650 Keystone Crossing, Indianapolis, IN 46240...     4.5
# 24  8431 N Michigan Rd, Indianapolis, IN 46268, Un...     4.2
# 35  35 N Illinois St, Indianapolis, IN 46204, Unit...     4.1
# 40  40 W Jackson Pl, Indianapolis, IN 46225, Unite...     4.4
# 41  45 S Illinois St, Indianapolis, IN 46204, Unit...     4.6
# 43   43 9th St, Indianapolis, IN 46204, United States     4.6
# 44  10 N Illinois St, Indianapolis, IN 46204, Unit...     4.2
# 45  765 Massachusetts Ave, Indianapolis, IN 46202,...     4.5
# 46  3089 N High School Rd, Indianapolis, IN 46224,...     4.4
# 47  47 S Pennsylvania St, Indianapolis, IN 46204, ...     4.6
# 48  130 S Pennsylvania St, Indianapolis, IN 46204,...     4.3
# 0   3850 S State Ave, Indianapolis, IN 46227, Unit...     4.5
# 3   501 W Maryland St, Indianapolis, IN 46225, Uni...     4.8
# 4   125 S Pennsylvania St, Indianapolis, IN 46204,...     4.7
# 0   1630 N Meridian St #240, Indianapolis, IN 4620...     0.0
# 2   1043 Virginia Ave UNIT 4, Indianapolis, IN 462...     4.6
# 3   39 W Jackson Pl #150, Indianapolis, IN 46225, ...     3.0

# %%
# Out:
#                                Name Category  \
# 0                            Livery     Food
# 1                          Union 50     Food
# 2           Maggiano's Little Italy     Food
# 3                 3 in 1 Restaurant     Food
# 7         Meridian Restaurant & Bar     Food
# 10                        Bluebeard     Food
# 11                        The Eagle     Food
# 12          Iron Skillet Restaurant     Food
# 14                             Vida     Food
# 15                       Yard House     Food
# 16                       Seasons 52     Food
# 24          Leonardo's Mexican Food     Food
# 35                    Buca di Beppo     Food
# 40                  1913 Restaurant     Food
# 41         Ruth's Chris Steak House     Food
# 43                           Comida     Food
# 44           Weber Grill Restaurant     Food
# 45                FortyFive Degrees     Food
# 46                         TACOS 46     Food
# 47      Prime 47- Indy's Steakhouse     Food
# 48  Pier 48 Fish House & Oyster Bar     Food
# 0       Kiesel Field at Key Stadium    Sport
# 3                     Victory Field    Sport
# 4             Gainbridge Fieldhouse    Sport
# 0              Classical Music Indy    Music
# 2          HI-FI Indy & HI-FI Annex    Music
# 3                     Music For All    Music
# 0              Classical Music Indy    Music
# 2          HI-FI Indy & HI-FI Annex    Music
# 3                     Music For All    Music
# 4           Good Games Indianapolis   Gaming
# 5                            One Up   Gaming
# 8                  Games to Die For   Gaming
# 11       LVL UP Gaming Lounge & Bar   Gaming
#
#                                               Address  Rating
# 0   720 N College Ave, Indianapolis, IN 46202, Uni...     4.7
# 1   620 N East St, Indianapolis, IN 46202, United ...     4.6
# 2   3550 E 86th St, Indianapolis, IN 46240, United...     4.4
# 3   1413 W 86th St, Indianapolis, IN 46260, United...     4.7
# 7   5694 N Meridian St, Indianapolis, IN 46208, Un...     4.5
# 10  653 Virginia Ave, Indianapolis, IN 46203, Unit...     4.7
# 11  310 Massachusetts Ave, Indianapolis, IN 46204,...     4.5
# 12  2489 W 30th St #2268, Indianapolis, IN 46222, ...     4.5
# 14  601 E New York St, Indianapolis, IN 46202, Uni...     4.8
# 15  15 W Maryland St, Indianapolis, IN 46204, Unit...     4.4
# 16  8650 Keystone Crossing, Indianapolis, IN 46240...     4.5
# 24  8431 N Michigan Rd, Indianapolis, IN 46268, Un...     4.2
# 35  35 N Illinois St, Indianapolis, IN 46204, Unit...     4.1
# 40  40 W Jackson Pl, Indianapolis, IN 46225, Unite...     4.4
# 41  45 S Illinois St, Indianapolis, IN 46204, Unit...     4.6
# 43   43 9th St, Indianapolis, IN 46204, United States     4.6
# 44  10 N Illinois St, Indianapolis, IN 46204, Unit...     4.2
# 45  765 Massachusetts Ave, Indianapolis, IN 46202,...     4.5
# 46  3089 N High School Rd, Indianapolis, IN 46224,...     4.4
# 47  47 S Pennsylvania St, Indianapolis, IN 46204, ...     4.6
# 48  130 S Pennsylvania St, Indianapolis, IN 46204,...     4.3
# 0   3850 S State Ave, Indianapolis, IN 46227, Unit...     4.5
# 3   501 W Maryland St, Indianapolis, IN 46225, Uni...     4.8
# 4   125 S Pennsylvania St, Indianapolis, IN 46204,...     4.7
# 0   1630 N Meridian St #240, Indianapolis, IN 4620...     0.0
# 2   1043 Virginia Ave UNIT 4, Indianapolis, IN 462...     4.6
# 3   39 W Jackson Pl #150, Indianapolis, IN 46225, ...     3.0
# 0   1630 N Meridian St #240, Indianapolis, IN 4620...     0.0
# 2   1043 Virginia Ave UNIT 4, Indianapolis, IN 462...     4.6
# 3   39 W Jackson Pl #150, Indianapolis, IN 46225, ...     3.0
# 4   111 S Meridian St, Indianapolis, IN 46225, Uni...     4.6
# 5   723 Broad Ripple Ave, Indianapolis, IN 46220, ...     4.5
# 8   1209 Indy Way, Indianapolis, IN 46214, United ...     4.7
# 11  7 Johnson Ave, Indianapolis, IN 46219, United ...     4.7

# %%
# Out:
#     Distance(Miles) from IUPUI  Distance(Minutes) from IUPUI  \
# 0                          2.7                          11.0
# 1                          2.5                          11.0
# 2                         20.0                          31.0
# 3                         10.7                          26.0
# 4                          7.1                          19.0
# 5                          3.0                          14.0
# 6                          1.9                           8.0
# 7                          3.5                          10.0
# 8                          2.2                           9.0
# 9                          2.0                           8.0
# 10                        20.2                          32.0
# 11                        11.1                          25.0
# 12                         2.1                           9.0
# 13                         2.0                           8.0
# 14                         2.0                           8.0
# 15                         2.3                           9.0
# 16                         2.0                           9.0
# 17                         2.8                          12.0
# 18                         6.5                          16.0
# 19                         2.1                           9.0
# 20                         2.2                           9.0
# 21                         8.4                          17.0
# 22                       732.0                          11.0
# 23                         2.2                           9.0
# 24                         3.0                          11.0
# 25                         4.0                          13.0
# 26                         2.1                          10.0
# 27                         3.0                          11.0
# 28                         4.0                          13.0
# 29                         2.1                          10.0
# 30                         2.0                           8.0
# 31                         8.1                          22.0
# 32                         7.4                          19.0
# 33                         6.3                          20.0
#
#     Distance(Miles) from Speak Easy  Distance(Minutes) from Speak Easy  \
# 0                               5.6                               17.0
# 1                               5.4                               15.0
# 2                               6.1                               18.0
# 3                               6.5                               16.0
# 4                               1.4                                5.0
# 5                               6.9                               22.0
# 6                               5.8                               18.0
# 7                               5.9                               15.0
# 8                               5.8                               17.0
# 9                               6.7                               21.0
# 10                              6.1                               18.0
# 11                              7.5                               20.0
# 12                              6.5                               21.0
# 13                              6.8                               21.0
# 14                              6.7                               21.0
# 15                              5.4                               16.0
# 16                              6.5                               20.0
# 17                              5.2                               15.0
# 18                              9.5                               23.0
# 19                              6.3                               19.0
# 20                              6.4                               19.0
# 21                             11.4                               28.0
# 22                            732.0                               11.0
# 23                              6.5                               20.0
# 24                              4.7                               13.0
# 25                              7.2                               23.0
# 26                              6.7                               22.0
# 27                              4.7                               13.0
# 28                              7.2                               23.0
# 29                              6.7                               22.0
# 30                              6.5                               20.0
# 31                              1.7                                6.0
# 32                             13.1                               31.0
# 33                              9.1                               23.0
#
#     Distance(Miles) from zWorks  Distance(Minutes) from zWorks  \
# 0                          18.3                           31.0
# 1                          18.0                           29.0
# 2                          11.3                           22.0
# 3                           7.3                           16.0
# 4                          12.6                           24.0
# 5                          19.2                           34.0
# 6                          18.1                           29.0
# 7                          13.6                           23.0
# 8                          18.4                           30.0
# 9                          18.1                           30.0
# 10                         11.3                           21.0
# 11                          4.7                           15.0
# 12                         18.5                           31.0
# 13                         18.2                           31.0
# 14                         18.1                           31.0
# 15                         17.4                           26.0
# 16                         18.5                           31.0
# 17                         18.1                           30.0
# 18                         11.3                           21.0
# 19                         18.3                           29.0
# 20                         18.4                           30.0
# 21                         26.9                           37.0
# 22                        743.0                           11.0
# 23                         18.4                           30.0
# 24                         16.7                           26.0
# 25                         19.6                           35.0
# 26                         18.6                           32.0
# 27                         16.7                           26.0
# 28                         19.6                           35.0
# 29                         18.6                           32.0
# 30                         18.3                           31.0
# 31                         12.4                           25.0
# 32                         14.9                           26.0
# 33                         24.7                           34.0
#
#     Distance(Miles) from Launch Fishers  Distance(Minutes) from Launch Fisher  \
# 0                                  20.5                                  28.0
# 1                                  16.1                                  30.0
# 2                                   8.4                                  20.0
# 3                                  14.8                                  25.0
# 4                                  13.1                                  26.0
# 5                                  22.0                                  33.0
# 6                                  21.0                                  30.0
# 7                                  17.1                                  32.0
# 8                                  21.0                                  28.0
# 9                                  21.9                                  33.0
# 10                                  9.6                                  20.0
# 11                                 17.0                                  27.0
# 12                                 21.7                                  32.0
# 13                                 21.8                                  33.0
# 14                                 21.9                                  33.0
# 15                                 20.6                                  28.0
# 16                                 21.6                                  32.0
# 17                                 20.6                                  28.0
# 18                                 26.9                                  35.0
# 19                                 21.5                                  31.0
# 20                                 21.6                                  31.0
# 21                                 24.8                                  34.0
# 22                                736.0                                  11.0
# 23                                 21.6                                  31.0
# 24                                 15.5                                  28.0
# 25                                 26.8                                  34.0
# 26                                 21.8                                  34.0
# 27                                 15.5                                  28.0
# 28                                 26.8                                  34.0
# 29                                 21.8                                  34.0
# 30                                 21.6                                  32.0
# 31                                 11.6                                  25.0
# 32                                 30.4                                  40.0
# 33                                 17.2                                  25.0
#
#     Distance(Miles) from IMA  Distance(Minutes) from IMA  \
# 0                        0.9                         4.0
# 1                        0.5                         3.0
# 2                       11.5                        30.0
# 3                       11.2                        25.0
# 4                        6.2                        18.0
# 5                        1.4                         7.0
# 6                      377.0                         1.0
# 7                        4.8                        14.0
# 8                        0.4                         2.0
# 9                        1.1                         6.0
# 10                      11.7                        31.0
# 11                      12.9                        24.0
# 12                       0.8                         5.0
# 13                       1.0                         6.0
# 14                       1.1                         6.0
# 15                       0.9                         5.0
# 16                       0.8                         5.0
# 17                       0.5                         4.0
# 18                       7.8                        21.0
# 19                       0.7                         4.0
# 20                       0.7                         4.0
# 21                       6.0                        13.0
# 22                     730.0                        11.0
# 23                       0.8                         4.0
# 24                       1.7                         7.0
# 25                       1.8                         8.0
# 26                       1.0                         7.0
# 27                       1.7                         7.0
# 28                       1.8                         8.0
# 29                       1.0                         7.0
# 30                       0.8                         5.0
# 31                       6.9                        21.0
# 32                       9.1                        24.0
# 33                       4.5                        12.0
#
#     Distance(Miles) from Launch Indy  Distance(Minutes) from Launch Indy
# 0                                1.9                                 8.0
# 1                                1.9                                10.0
# 2                               12.7                                34.0
# 3                               11.7                                27.0
# 4                                7.0                                21.0
# 5                                1.0                                 6.0
# 6                                1.3                                 7.0
# 7                                5.3                                15.0
# 8                                1.4                                 7.0
# 9                                0.6                                 3.0
# 10                              12.9                                35.0
# 11                              13.4                                26.0
# 12                               0.7                                 3.0
# 13                               0.4                                 2.0
# 14                               0.6                                 3.0
# 15                               1.7                                 8.0
# 16                               0.7                                 3.0
# 17                               2.0                                 9.0
# 18                              12.7                                18.0
# 19                               0.9                                 6.0
# 20                               0.8                                 4.0
# 21                               5.5                                10.0
# 22                             731.0                                11.0
# 23                               0.5                                 3.0
# 24                               2.4                                10.0
# 25                               1.6                                 5.0
# 26                               0.4                                 2.0
# 27                               2.4                                10.0
# 28                               1.6                                 5.0
# 29                               0.4                                 2.0
# 30                               0.4                                 3.0
# 31                               8.0                                24.0
# 32                              12.9                                20.0
# 33                               6.1                                14.0

# %%
# Out:
#     Distance(Miles) from IUPUI  Distance(Minutes) from IUPUI  \
# 0                          2.7                          11.0
# 1                          2.5                          11.0
# 2                         20.0                          31.0
# 3                         10.7                          26.0
# 4                          7.1                          19.0
# 5                          3.0                          14.0
# 6                          1.9                           8.0
# 7                          3.5                          10.0
# 8                          2.2                           9.0
# 9                          2.0                           8.0
# 10                        20.2                          32.0
# 11                        11.1                          25.0
# 12                         2.1                           9.0
# 13                         2.0                           8.0
# 14                         2.0                           8.0
# 15                         2.3                           9.0
# 16                         2.0                           9.0
# 17                         2.8                          12.0
# 18                         6.5                          16.0
# 19                         2.1                           9.0
# 20                         2.2                           9.0
# 21                         8.4                          17.0
# 23                         2.2                           9.0
# 24                         3.0                          11.0
# 25                         4.0                          13.0
# 26                         2.1                          10.0
# 27                         3.0                          11.0
# 28                         4.0                          13.0
# 29                         2.1                          10.0
# 30                         2.0                           8.0
# 31                         8.1                          22.0
# 32                         7.4                          19.0
# 33                         6.3                          20.0
#
#     Distance(Miles) from Speak Easy  Distance(Minutes) from Speak Easy  \
# 0                               5.6                               17.0
# 1                               5.4                               15.0
# 2                               6.1                               18.0
# 3                               6.5                               16.0
# 4                               1.4                                5.0
# 5                               6.9                               22.0
# 6                               5.8                               18.0
# 7                               5.9                               15.0
# 8                               5.8                               17.0
# 9                               6.7                               21.0
# 10                              6.1                               18.0
# 11                              7.5                               20.0
# 12                              6.5                               21.0
# 13                              6.8                               21.0
# 14                              6.7                               21.0
# 15                              5.4                               16.0
# 16                              6.5                               20.0
# 17                              5.2                               15.0
# 18                              9.5                               23.0
# 19                              6.3                               19.0
# 20                              6.4                               19.0
# 21                             11.4                               28.0
# 23                              6.5                               20.0
# 24                              4.7                               13.0
# 25                              7.2                               23.0
# 26                              6.7                               22.0
# 27                              4.7                               13.0
# 28                              7.2                               23.0
# 29                              6.7                               22.0
# 30                              6.5                               20.0
# 31                              1.7                                6.0
# 32                             13.1                               31.0
# 33                              9.1                               23.0
#
#     Distance(Miles) from zWorks  Distance(Minutes) from zWorks  \
# 0                          18.3                           31.0
# 1                          18.0                           29.0
# 2                          11.3                           22.0
# 3                           7.3                           16.0
# 4                          12.6                           24.0
# 5                          19.2                           34.0
# 6                          18.1                           29.0
# 7                          13.6                           23.0
# 8                          18.4                           30.0
# 9                          18.1                           30.0
# 10                         11.3                           21.0
# 11                          4.7                           15.0
# 12                         18.5                           31.0
# 13                         18.2                           31.0
# 14                         18.1                           31.0
# 15                         17.4                           26.0
# 16                         18.5                           31.0
# 17                         18.1                           30.0
# 18                         11.3                           21.0
# 19                         18.3                           29.0
# 20                         18.4                           30.0
# 21                         26.9                           37.0
# 23                         18.4                           30.0
# 24                         16.7                           26.0
# 25                         19.6                           35.0
# 26                         18.6                           32.0
# 27                         16.7                           26.0
# 28                         19.6                           35.0
# 29                         18.6                           32.0
# 30                         18.3                           31.0
# 31                         12.4                           25.0
# 32                         14.9                           26.0
# 33                         24.7                           34.0
#
#     Distance(Miles) from Launch Fishers  Distance(Minutes) from Launch Fisher  \
# 0                                  20.5                                  28.0
# 1                                  16.1                                  30.0
# 2                                   8.4                                  20.0
# 3                                  14.8                                  25.0
# 4                                  13.1                                  26.0
# 5                                  22.0                                  33.0
# 6                                  21.0                                  30.0
# 7                                  17.1                                  32.0
# 8                                  21.0                                  28.0
# 9                                  21.9                                  33.0
# 10                                  9.6                                  20.0
# 11                                 17.0                                  27.0
# 12                                 21.7                                  32.0
# 13                                 21.8                                  33.0
# 14                                 21.9                                  33.0
# 15                                 20.6                                  28.0
# 16                                 21.6                                  32.0
# 17                                 20.6                                  28.0
# 18                                 26.9                                  35.0
# 19                                 21.5                                  31.0
# 20                                 21.6                                  31.0
# 21                                 24.8                                  34.0
# 23                                 21.6                                  31.0
# 24                                 15.5                                  28.0
# 25                                 26.8                                  34.0
# 26                                 21.8                                  34.0
# 27                                 15.5                                  28.0
# 28                                 26.8                                  34.0
# 29                                 21.8                                  34.0
# 30                                 21.6                                  32.0
# 31                                 11.6                                  25.0
# 32                                 30.4                                  40.0
# 33                                 17.2                                  25.0
#
#     Distance(Miles) from IMA  Distance(Minutes) from IMA  \
# 0                        0.9                         4.0
# 1                        0.5                         3.0
# 2                       11.5                        30.0
# 3                       11.2                        25.0
# 4                        6.2                        18.0
# 5                        1.4                         7.0
# 6                      377.0                         1.0
# 7                        4.8                        14.0
# 8                        0.4                         2.0
# 9                        1.1                         6.0
# 10                      11.7                        31.0
# 11                      12.9                        24.0
# 12                       0.8                         5.0
# 13                       1.0                         6.0
# 14                       1.1                         6.0
# 15                       0.9                         5.0
# 16                       0.8                         5.0
# 17                       0.5                         4.0
# 18                       7.8                        21.0
# 19                       0.7                         4.0
# 20                       0.7                         4.0
# 21                       6.0                        13.0
# 23                       0.8                         4.0
# 24                       1.7                         7.0
# 25                       1.8                         8.0
# 26                       1.0                         7.0
# 27                       1.7                         7.0
# 28                       1.8                         8.0
# 29                       1.0                         7.0
# 30                       0.8                         5.0
# 31                       6.9                        21.0
# 32                       9.1                        24.0
# 33                       4.5                        12.0
#
#     Distance(Miles) from Launch Indy  Distance(Minutes) from Launch Indy
# 0                                1.9                                 8.0
# 1                                1.9                                10.0
# 2                               12.7                                34.0
# 3                               11.7                                27.0
# 4                                7.0                                21.0
# 5                                1.0                                 6.0
# 6                                1.3                                 7.0
# 7                                5.3                                15.0
# 8                                1.4                                 7.0
# 9                                0.6                                 3.0
# 10                              12.9                                35.0
# 11                              13.4                                26.0
# 12                               0.7                                 3.0
# 13                               0.4                                 2.0
# 14                               0.6                                 3.0
# 15                               1.7                                 8.0
# 16                               0.7                                 3.0
# 17                               2.0                                 9.0
# 18                              12.7                                18.0
# 19                               0.9                                 6.0
# 20                               0.8                                 4.0
# 21                               5.5                                10.0
# 23                               0.5                                 3.0
# 24                               2.4                                10.0
# 25                               1.6                                 5.0
# 26                               0.4                                 2.0
# 27                               2.4                                10.0
# 28                               1.6                                 5.0
# 29                               0.4                                 2.0
# 30                               0.4                                 3.0
# 31                               8.0                                24.0
# 32                              12.9                                20.0
# 33                               6.1                                14.0

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/yv/wlxrjlk56pz18p1xdflckzx80000gn/T/ipykernel_85440/1274931917.py in <module>
# ----> 1 df5.to_csv('Locations of Interest in Indianapolis Area and Distance from Housing/Coworking Spaces', sep='\t')
#
# ~/.julia/conda/3/lib/python3.9/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~/.julia/conda/3/lib/python3.9/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~/.julia/conda/3/lib/python3.9/site-packages/pandas/io/formats/csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# ~/.julia/conda/3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Locations of Interest in Indianapolis Area and Distance from Housing/Coworking Spaces'

# %%
# Out:
#     index                             Name Category  \
# 0       0                           Livery     Food
# 1       1                         Union 50     Food
# 2       2          Maggiano's Little Italy     Food
# 3       3                3 in 1 Restaurant     Food
# 4       7        Meridian Restaurant & Bar     Food
# 5      10                        Bluebeard     Food
# 6      11                        The Eagle     Food
# 7      12          Iron Skillet Restaurant     Food
# 8      14                             Vida     Food
# 9      15                       Yard House     Food
# 10     16                       Seasons 52     Food
# 11     24          Leonardo's Mexican Food     Food
# 12     35                    Buca di Beppo     Food
# 13     40                  1913 Restaurant     Food
# 14     41         Ruth's Chris Steak House     Food
# 15     43                           Comida     Food
# 16     44           Weber Grill Restaurant     Food
# 17     45                FortyFive Degrees     Food
# 18     46                         TACOS 46     Food
# 19     47      Prime 47- Indy's Steakhouse     Food
# 20     48  Pier 48 Fish House & Oyster Bar     Food
# 21      0      Kiesel Field at Key Stadium    Sport
# 22      3                    Victory Field    Sport
# 23      4            Gainbridge Fieldhouse    Sport
# 24      0             Classical Music Indy    Music
# 25      2         HI-FI Indy & HI-FI Annex    Music
# 26      3                    Music For All    Music
# 27      0             Classical Music Indy    Music
# 28      2         HI-FI Indy & HI-FI Annex    Music
# 29      3                    Music For All    Music
# 30      4          Good Games Indianapolis   Gaming
# 31      5                           One Up   Gaming
# 32      8                 Games to Die For   Gaming
# 33     11       LVL UP Gaming Lounge & Bar   Gaming
#
#                                               Address  Rating  \
# 0   720 N College Ave, Indianapolis, IN 46202, Uni...     4.7
# 1   620 N East St, Indianapolis, IN 46202, United ...     4.6
# 2   3550 E 86th St, Indianapolis, IN 46240, United...     4.4
# 3   1413 W 86th St, Indianapolis, IN 46260, United...     4.7
# 4   5694 N Meridian St, Indianapolis, IN 46208, Un...     4.5
# 5   653 Virginia Ave, Indianapolis, IN 46203, Unit...     4.7
# 6   310 Massachusetts Ave, Indianapolis, IN 46204,...     4.5
# 7   2489 W 30th St #2268, Indianapolis, IN 46222, ...     4.5
# 8   601 E New York St, Indianapolis, IN 46202, Uni...     4.8
# 9   15 W Maryland St, Indianapolis, IN 46204, Unit...     4.4
# 10  8650 Keystone Crossing, Indianapolis, IN 46240...     4.5
# 11  8431 N Michigan Rd, Indianapolis, IN 46268, Un...     4.2
# 12  35 N Illinois St, Indianapolis, IN 46204, Unit...     4.1
# 13  40 W Jackson Pl, Indianapolis, IN 46225, Unite...     4.4
# 14  45 S Illinois St, Indianapolis, IN 46204, Unit...     4.6
# 15   43 9th St, Indianapolis, IN 46204, United States     4.6
# 16  10 N Illinois St, Indianapolis, IN 46204, Unit...     4.2
# 17  765 Massachusetts Ave, Indianapolis, IN 46202,...     4.5
# 18  3089 N High School Rd, Indianapolis, IN 46224,...     4.4
# 19  47 S Pennsylvania St, Indianapolis, IN 46204, ...     4.6
# 20  130 S Pennsylvania St, Indianapolis, IN 46204,...     4.3
# 21  3850 S State Ave, Indianapolis, IN 46227, Unit...     4.5
# 22  501 W Maryland St, Indianapolis, IN 46225, Uni...     4.8
# 23  125 S Pennsylvania St, Indianapolis, IN 46204,...     4.7
# 24  1630 N Meridian St #240, Indianapolis, IN 4620...     0.0
# 25  1043 Virginia Ave UNIT 4, Indianapolis, IN 462...     4.6
# 26  39 W Jackson Pl #150, Indianapolis, IN 46225, ...     3.0
# 27  1630 N Meridian St #240, Indianapolis, IN 4620...     0.0
# 28  1043 Virginia Ave UNIT 4, Indianapolis, IN 462...     4.6
# 29  39 W Jackson Pl #150, Indianapolis, IN 46225, ...     3.0
# 30  111 S Meridian St, Indianapolis, IN 46225, Uni...     4.6
# 31  723 Broad Ripple Ave, Indianapolis, IN 46220, ...     4.5
# 32  1209 Indy Way, Indianapolis, IN 46214, United ...     4.7
# 33  7 Johnson Ave, Indianapolis, IN 46219, United ...     4.7
#
#     Distance(Miles) from IUPUI  Distance(Minutes) from IUPUI  \
# 0                          2.7                          11.0
# 1                          2.5                          11.0
# 2                         20.0                          31.0
# 3                         10.7                          26.0
# 4                          7.1                          19.0
# 5                          3.0                          14.0
# 6                          1.9                           8.0
# 7                          3.5                          10.0
# 8                          2.2                           9.0
# 9                          2.0                           8.0
# 10                        20.2                          32.0
# 11                        11.1                          25.0
# 12                         2.1                           9.0
# 13                         2.0                           8.0
# 14                         2.0                           8.0
# 15                         2.3                           9.0
# 16                         2.0                           9.0
# 17                         2.8                          12.0
# 18                         6.5                          16.0
# 19                         2.1                           9.0
# 20                         2.2                           9.0
# 21                         8.4                          17.0
# 22                       732.0                          11.0
# 23                         2.2                           9.0
# 24                         3.0                          11.0
# 25                         4.0                          13.0
# 26                         2.1                          10.0
# 27                         3.0                          11.0
# 28                         4.0                          13.0
# 29                         2.1                          10.0
# 30                         2.0                           8.0
# 31                         8.1                          22.0
# 32                         7.4                          19.0
# 33                         6.3                          20.0
#
#     Distance(Miles) from Speak Easy  Distance(Minutes) from Speak Easy  \
# 0                               5.6                               17.0
# 1                               5.4                               15.0
# 2                               6.1                               18.0
# 3                               6.5                               16.0
# 4                               1.4                                5.0
# 5                               6.9                               22.0
# 6                               5.8                               18.0
# 7                               5.9                               15.0
# 8                               5.8                               17.0
# 9                               6.7                               21.0
# 10                              6.1                               18.0
# 11                              7.5                               20.0
# 12                              6.5                               21.0
# 13                              6.8                               21.0
# 14                              6.7                               21.0
# 15                              5.4                               16.0
# 16                              6.5                               20.0
# 17                              5.2                               15.0
# 18                              9.5                               23.0
# 19                              6.3                               19.0
# 20                              6.4                               19.0
# 21                             11.4                               28.0
# 22                            732.0                               11.0
# 23                              6.5                               20.0
# 24                              4.7                               13.0
# 25                              7.2                               23.0
# 26                              6.7                               22.0
# 27                              4.7                               13.0
# 28                              7.2                               23.0
# 29                              6.7                               22.0
# 30                              6.5                               20.0
# 31                              1.7                                6.0
# 32                             13.1                               31.0
# 33                              9.1                               23.0
#
#     Distance(Miles) from zWorks  Distance(Minutes) from zWorks  \
# 0                          18.3                           31.0
# 1                          18.0                           29.0
# 2                          11.3                           22.0
# 3                           7.3                           16.0
# 4                          12.6                           24.0
# 5                          19.2                           34.0
# 6                          18.1                           29.0
# 7                          13.6                           23.0
# 8                          18.4                           30.0
# 9                          18.1                           30.0
# 10                         11.3                           21.0
# 11                          4.7                           15.0
# 12                         18.5                           31.0
# 13                         18.2                           31.0
# 14                         18.1                           31.0
# 15                         17.4                           26.0
# 16                         18.5                           31.0
# 17                         18.1                           30.0
# 18                         11.3                           21.0
# 19                         18.3                           29.0
# 20                         18.4                           30.0
# 21                         26.9                           37.0
# 22                        743.0                           11.0
# 23                         18.4                           30.0
# 24                         16.7                           26.0
# 25                         19.6                           35.0
# 26                         18.6                           32.0
# 27                         16.7                           26.0
# 28                         19.6                           35.0
# 29                         18.6                           32.0
# 30                         18.3                           31.0
# 31                         12.4                           25.0
# 32                         14.9                           26.0
# 33                         24.7                           34.0
#
#     Distance(Miles) from Launch Fishers  Distance(Minutes) from Launch Fisher  \
# 0                                  20.5                                  28.0
# 1                                  16.1                                  30.0
# 2                                   8.4                                  20.0
# 3                                  14.8                                  25.0
# 4                                  13.1                                  26.0
# 5                                  22.0                                  33.0
# 6                                  21.0                                  30.0
# 7                                  17.1                                  32.0
# 8                                  21.0                                  28.0
# 9                                  21.9                                  33.0
# 10                                  9.6                                  20.0
# 11                                 17.0                                  27.0
# 12                                 21.7                                  32.0
# 13                                 21.8                                  33.0
# 14                                 21.9                                  33.0
# 15                                 20.6                                  28.0
# 16                                 21.6                                  32.0
# 17                                 20.6                                  28.0
# 18                                 26.9                                  35.0
# 19                                 21.5                                  31.0
# 20                                 21.6                                  31.0
# 21                                 24.8                                  34.0
# 22                                736.0                                  11.0
# 23                                 21.6                                  31.0
# 24                                 15.5                                  28.0
# 25                                 26.8                                  34.0
# 26                                 21.8                                  34.0
# 27                                 15.5                                  28.0
# 28                                 26.8                                  34.0
# 29                                 21.8                                  34.0
# 30                                 21.6                                  32.0
# 31                                 11.6                                  25.0
# 32                                 30.4                                  40.0
# 33                                 17.2                                  25.0
#
#     Distance(Miles) from IMA  Distance(Minutes) from IMA  \
# 0                        0.9                         4.0
# 1                        0.5                         3.0
# 2                       11.5                        30.0
# 3                       11.2                        25.0
# 4                        6.2                        18.0
# 5                        1.4                         7.0
# 6                      377.0                         1.0
# 7                        4.8                        14.0
# 8                        0.4                         2.0
# 9                        1.1                         6.0
# 10                      11.7                        31.0
# 11                      12.9                        24.0
# 12                       0.8                         5.0
# 13                       1.0                         6.0
# 14                       1.1                         6.0
# 15                       0.9                         5.0
# 16                       0.8                         5.0
# 17                       0.5                         4.0
# 18                       7.8                        21.0
# 19                       0.7                         4.0
# 20                       0.7                         4.0
# 21                       6.0                        13.0
# 22                     730.0                        11.0
# 23                       0.8                         4.0
# 24                       1.7                         7.0
# 25                       1.8                         8.0
# 26                       1.0                         7.0
# 27                       1.7                         7.0
# 28                       1.8                         8.0
# 29                       1.0                         7.0
# 30                       0.8                         5.0
# 31                       6.9                        21.0
# 32                       9.1                        24.0
# 33                       4.5                        12.0
#
#     Distance(Miles) from Launch Indy  Distance(Minutes) from Launch Indy
# 0                                1.9                                 8.0
# 1                                1.9                                10.0
# 2                               12.7                                34.0
# 3                               11.7                                27.0
# 4                                7.0                                21.0
# 5                                1.0                                 6.0
# 6                                1.3                                 7.0
# 7                                5.3                                15.0
# 8                                1.4                                 7.0
# 9                                0.6                                 3.0
# 10                              12.9                                35.0
# 11                              13.4                                26.0
# 12                               0.7                                 3.0
# 13                               0.4                                 2.0
# 14                               0.6                                 3.0
# 15                               1.7                                 8.0
# 16                               0.7                                 3.0
# 17                               2.0                                 9.0
# 18                              12.7                                18.0
# 19                               0.9                                 6.0
# 20                               0.8                                 4.0
# 21                               5.5                                10.0
# 22                             731.0                                11.0
# 23                               0.5                                 3.0
# 24                               2.4                                10.0
# 25                               1.6                                 5.0
# 26                               0.4                                 2.0
# 27                               2.4                                10.0
# 28                               1.6                                 5.0
# 29                               0.4                                 2.0
# 30                               0.4                                 3.0
# 31                               8.0                                24.0
# 32                              12.9                                20.0
# 33                               6.1                                14.0
